# %%
print('hello world')
# Out:
# hello world

# %%
c_id = 123456789
c_name = "kiki Marsh"
c_gender = "Female"
c_dob = "02-10-2002"
c_dln = "DL123456789"
c_apn = "AP123456789"

# %%
print(c_name)
# Out:
# kiki Marsh
