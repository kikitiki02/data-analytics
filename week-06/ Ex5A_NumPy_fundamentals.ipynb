# %% [markdown]
# # NumPy fundamentals

# %%
import numpy as np

# %% [markdown]
# ## Array Basics

# %%
fruits = ["apple", "banana", "cherry", "date"]

# %%
arr_1 = np.array(fruits)

# %%
print(arr_1)
# Out:
# ['apple' 'banana' 'cherry' 'date']

# %%
print(arr_1.dtype)
# Out:
# <U6

# %%
# The U means unicode and the 6 is the max string out of all the fruits individually

# %%
arr_2 = np.array([[10,11,12],[13,14,15]])

# %%
print(arr_2)
# Out:
# [[10 11 12]
#  [13 14 15]]

# %%
print(arr_2.T)
# Out:
# [[10 13]
#  [11 14]
#  [12 15]]

# %%
# The transpose didn't change the value it just listed it a different way

# %%
arr_3 = np.array([[1,3,5],[2,4,6]])

# %%
print(arr_3)
# Out:
# [[1 3 5]
#  [2 4 6]]

# %%
arr_4 = np.array([arr_3[0,2],arr_3[1,1]])

# %%
print(arr_4)
# Out:
# [5 4]

# %%
arr_5 = np.ones((2,2,2), dtype=int)

# %%
print(arr_5)
# Out:
# [[[1 1]
#   [1 1]]
#
#  [[1 1]
#   [1 1]]]
