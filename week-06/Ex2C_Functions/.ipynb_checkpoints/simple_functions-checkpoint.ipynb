# %% [markdown]
# # Lab 1 of Exercise 2.C, working
# # with defining custom functions

# %%
def favorite_things(name, movie, music):
    return name, movie, music
print(favorite_things("Kiki", "Ponyo", "Midnight Sun"))
# Out:
# ('Kiki', 'Ponyo', 'Midnight Sun')

# %%
def why_im_here(purpose):
    return purpose
print(why_im_here("I'm here to learn data analytics for a future career"))
# Out:
# I'm here to learn data analytics for a future career

# %%
def favorite_place(place, why):
    return place,why
print(favorite_place("Texas", "Because majority of my family is there and it's not cold"))
# Out:
# ('Texas', "Because majority of my family is there and it's not cold")
