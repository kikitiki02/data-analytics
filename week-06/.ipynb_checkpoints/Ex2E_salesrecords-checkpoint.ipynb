# %% [markdown]
# # Sales Records Analysis
# ### Author: Kiki :)
# ### Exercise 2.E Using functions for analyzing data
# This notebook analyzes a small sales dataset using Python functions.
# Each function takes the full dataset as its first argument.

# %%
sales_data = [
('Laptop', 'East', 1200.00),
('Phone', 'West', 850.00),
('Tablet', 'East', 400.00),
('Monitor', 'South', 650.00),
('Keyboard', 'West', 75.00),
('Laptop', 'South', 1150.00),
('Phone', 'East', 900.00),
('Tablet', 'West', 425.00),
('Monitor', 'East', 680.00),
('Keyboard', 'South', 80.00),
('Laptop', 'West', 1300.00),
('Phone', 'West', 820.00),
]

# %% [markdown]
# ## Lab 1. Total sales by region

# %%
def region_total(data, region):
    return sum(amt for _, r, amt in data if r == region)

# %%
print(region_total(sales_data, 'East'))
print(region_total(sales_data, 'West'))
print(region_total(sales_data, 'South'))
# Out:
# 3180.0
# 3470.0
# 1880.0

# %% [markdown]
# ## Lab 2. Count of sales by region

# %%
def region_count(data, region):
    return sum(1 for _, r, amt in data if r == region)

# %%
print(region_count(sales_data, 'East'))
print(region_count(sales_data, 'West'))
print(region_count(sales_data, 'South'))
# Out:
# 4
# 5
# 3

# %% [markdown]
# ## Lab 3. Average sale amount by region

# %%
def region_average(data, region):
    count = region_count(data, region)

    if count == 0:
        return 0

    return region_total(data, region) / count

# %%
print(region_average(sales_data, 'East'))
print(region_average(sales_data, 'West'))
print(region_average(sales_data, 'South'))
# Out:
# 795.0
# 694.0
# 626.6666666666666

# %%
print(region_average(sales_data, 'North'))
# Out:
# 0

# %% [markdown]
# ## Lab 4. Filter by sale amount

# %%
def sales_above(data, threshold):
    return [record for record in data if record[2] > threshold]

# %%
results = sales_above(sales_data, 500)
for record in results:
    print(record)
# Out:
# ('Laptop', 'East', 1200.0)
# ('Phone', 'West', 850.0)
# ('Monitor', 'South', 650.0)
# ('Laptop', 'South', 1150.0)
# ('Phone', 'East', 900.0)
# ('Monitor', 'East', 680.0)
# ('Laptop', 'West', 1300.0)
# ('Phone', 'West', 820.0)

# %%
def sales_below(data, threshold):
    return [record for record in data if record[2] < threshold]

# %%
results = sales_below(sales_data, 500)
for record in results:
    print(record)
# Out:
# ('Tablet', 'East', 400.0)
# ('Keyboard', 'West', 75.0)
# ('Tablet', 'West', 425.0)
# ('Keyboard', 'South', 80.0)

# %% [markdown]
# ## Lab 5. Top and bottom sale

# %%
def top_sale(data):
    return max(data, key=lambda s: s[2])
print(top_sale(sales_data))
# Out:
# ('Laptop', 'West', 1300.0)

# %%
def bottom_sale(data):
    return min(data, key=lambda s: s[2])
print(bottom_sale(sales_data))
# Out:
# ('Keyboard', 'West', 75.0)

# %% [markdown]
# The top sale was a Laptop in the West region for $1,300.00.

# %% [markdown]
# ## Lab 6. Apply a discount

# %%
def apply_discount(data, discount_pct):
    return list(map(lambda s: (s[0], s[1], s[2] * (1 - discount_pct)),data))

# %%
dis_sale = apply_discount(sales_data, 0.15)
for record in dis_sale[:3]:
    print(record)
# Out:
# ('Laptop', 'East', 1020.0)
# ('Phone', 'West', 722.5)
# ('Tablet', 'East', 340.0)

# %% [markdown]
# ## Lab 7. Unique regions

# %%
def unique_regions(data):
    return sorted(set(r for _, r, _ in data))

# %%
print(unique_regions(sales_data)) # can be used as different categories in a analysis
# Out:
# ['East', 'South', 'West']

# %% [markdown]
# ## Lab 8. Region summary

# %%
def region_summary(data, region):
    region_data = [row for row in data if row[1] == region]
    return {
        "region": region,
        "total": region_total(region_data, region),
        "count": region_count(region_data, region),
        "average": region_average(region_data, region),
        "top_sale": top_sale(region_data)}

# %%
print(region_summary(sales_data, "West"))
# Out:
# {'region': 'West', 'total': 3470.0, 'count': 5, 'average': 694.0, 'top_sale': ('Laptop', 'West', 1300.0)}

# %% [markdown]
# ## Lab 9. Full summary

# %%
for region in unique_regions(sales_data):
    print(region_summary(sales_data, region))
# Out:
# {'region': 'East', 'total': 3180.0, 'count': 4, 'average': 795.0, 'top_sale': ('Laptop', 'East', 1200.0)}
# {'region': 'South', 'total': 1880.0, 'count': 3, 'average': 626.6666666666666, 'top_sale': ('Laptop', 'South', 1150.0)}
# {'region': 'West', 'total': 3470.0, 'count': 5, 'average': 694.0, 'top_sale': ('Laptop', 'West', 1300.0)}

# %% [markdown]
# Basically I've learned that there are different ways to find data in a set of sales data, the summary part was a bit difficult though.
